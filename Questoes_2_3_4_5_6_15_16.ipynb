# %% [markdown]
# <a href="https://colab.research.google.com/github/moraesleonardo/MachineLearning_BigData/blob/main/Questoes_2_3_4_5_6_15_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Trabalho Leonardo Bastos Moraes
import pandas as pd

# %%
dataset = pd.read_excel('/dataset_v3.xls')

# %%
dataset.head(5)
# Out:
#    ID                       Datetime  Temperature   Humidity    Pressure  \
# 0   0  Mon; 20 May 2019 19:08:34 GMT    23.005257  33.060454  972.784433
# 1   1  Mon; 20 May 2019 19:08:35 GMT    22.989942  33.095483  972.844472
# 2   2  Mon; 20 May 2019 19:08:36 GMT    23.000152  33.080467  972.804446
# 3   3  Mon; 20 May 2019 19:08:36 GMT    22.989942  33.105487  972.732905
# 4   4  Mon; 20 May 2019 19:08:37 GMT    22.995047  33.105482  972.768675
#
#    Co2 Gas  PM2,5  PM10 Daytime
# 0      626    3.8   8.8   Night
# 1      627    3.8   8.9   Night
# 2      627    3.8   8.9   Night
# 3      626    3.8   8.9   Night
# 4      626    3.7   8.3   Night

# %%
# Importando bilbiotecas

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(data=dataset, x='Humidity', bins=30, kde=True)
# Out:
# <Axes: xlabel='Humidity', ylabel='Count'>

# %%
sns.histplot(data=dataset, x='Temperature', bins=30, kde=True)
# Out:
# <Axes: xlabel='Temperature', ylabel='Count'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib

# %%
dataset1 = pd.read_excel('/content/dataset_v9.xls')

# %%
len(dataset1.index)
# Out:
# 4100

# %%
dataset1.head(5)
# Out:
#    ID  day  hora  minuto  Datetime  Temperature   Humidity    Pressure  \
# 0   0   20    19       8  19:08:34    23.005257  33.060454  972.784433
# 1   1   20    19       8  19:08:35    22.989942  33.095483  972.844472
# 2   2   20    19       8  19:08:36    23.000152  33.080467  972.804446
# 3   3   20    19       8  19:08:36    22.989942  33.105487  972.732905
# 4   4   20    19       8  19:08:37    22.995047  33.105482  972.768675
#
#    Co2 Gas  PM2,5  PM10 Daytime
# 0      626    3.8   8.8   Night
# 1      627    3.8   8.9   Night
# 2      627    3.8   8.9   Night
# 3      626    3.8   8.9   Night
# 4      626    3.7   8.3   Night

# %%
sns.boxplot(x='day', y='Pressure', data=dataset1)
# Out:
# <Axes: xlabel='day', ylabel='Pressure'>

# %% [markdown]
# # Conforme gráfico acima, foi observado um outlier que será desconsiderado para a análise

# %%
dataset2 = pd.read_excel('/content/dataset_v10.xls')

# %%
dataset2.head(5)
# Out:
#    ID  day  hora  minuto  Datetime  Temperature   Humidity    Pressure  \
# 0   0   20    19       8  19:08:34    23.005257  33.060454  972.784433
# 1   1   20    19       8  19:08:35    22.989942  33.095483  972.844472
# 2   2   20    19       8  19:08:36    23.000152  33.080467  972.804446
# 3   3   20    19       8  19:08:36    22.989942  33.105487  972.732905
# 4   4   20    19       8  19:08:37    22.995047  33.105482  972.768675
#
#    Co2 Gas  PM2,5  PM10 Daytime
# 0      626    3.8   8.8   Night
# 1      627    3.8   8.9   Night
# 2      627    3.8   8.9   Night
# 3      626    3.8   8.9   Night
# 4      626    3.7   8.3   Night

# %%
sns.jointplot(x='minuto', y='Pressure', data=dataset2, hue='hora', palette='icefire')

# %%
dataset1 = pd.read_excel('/content/dataset_v9.xls')

# %%
# número de linhas da tabela
len(dataset1.index)
# Out:
# 4100

# %%
# tabela em ordem ascendente considerando os valores de temperatura e de humidade
dataset_exec5 = dataset1.sort_values(by=['Temperature', 'Humidity'], ascending=True)
dataset_exec5
# Out:
#         ID  day  hora  minuto  Datetime  Temperature   Humidity    Pressure  \
# 816    816   20    19      17  19:17:34    22.877633  34.410469  972.671129
# 197    197   20    19      10  19:10:44    22.892948  33.930587  972.694766
# 204    204   20    19      10  19:10:49    22.892948  33.940586  972.750540
# 196    196   20    19      10  19:10:43    22.898053  33.915593  972.730532
# 199    199   20    19      10  19:10:45    22.898053  33.920592  972.702645
# ...    ...  ...   ...     ...       ...          ...        ...         ...
# 3379  4279   21     6      41  06:41:55    27.630502  22.006332  972.008838
# 3382  4282   21     6      42  06:42:00    27.630502  22.117876  971.980740
# 3380  4280   21     6      41  06:41:57    27.635608  22.046755  972.016674
# 3378  4278   21     6      41  06:41:53    27.635608  22.051825  972.016674
# 3377  4277   21     6      41  06:41:52    27.640713  22.132810  971.940215
#
#       Co2 Gas  PM2,5  PM10 Daytime
# 816       632    4.3   9.2   Night
# 197       628    4.0   7.6   Night
# 204       627    4.1   9.1   Night
# 196       628    4.0   7.6   Night
# 199       627    4.1   8.6   Night
# ...       ...    ...   ...     ...
# 3379      641    8.6  14.1     Day
# 3382      637    8.2  13.9     Day
# 3380      640    8.5  13.9     Day
# 3378      643    8.8  14.7     Day
# 3377      643    8.9  15.4     Day
#
# [4100 rows x 12 columns]

# %%
#Criado um novo Índice level_0
dataset_exec5.reset_index(inplace=True)
dataset_exec5
# Out:
#       level_0  index    ID  day  hora  minuto  Datetime  Temperature  \
# 0           0    816   816   20    19      17  19:17:34    22.877633
# 1           1    197   197   20    19      10  19:10:44    22.892948
# 2           2    204   204   20    19      10  19:10:49    22.892948
# 3           3    196   196   20    19      10  19:10:43    22.898053
# 4           4    199   199   20    19      10  19:10:45    22.898053
# ...       ...    ...   ...  ...   ...     ...       ...          ...
# 4095     4095   3379  4279   21     6      41  06:41:55    27.630502
# 4096     4096   3382  4282   21     6      42  06:42:00    27.630502
# 4097     4097   3380  4280   21     6      41  06:41:57    27.635608
# 4098     4098   3378  4278   21     6      41  06:41:53    27.635608
# 4099     4099   3377  4277   21     6      41  06:41:52    27.640713
#
#        Humidity    Pressure  Co2 Gas  PM2,5  PM10 Daytime
# 0     34.410469  972.671129      632    4.3   9.2   Night
# 1     33.930587  972.694766      628    4.0   7.6   Night
# 2     33.940586  972.750540      627    4.1   9.1   Night
# 3     33.915593  972.730532      628    4.0   7.6   Night
# 4     33.920592  972.702645      627    4.1   8.6   Night
# ...         ...         ...      ...    ...   ...     ...
# 4095  22.006332  972.008838      641    8.6  14.1     Day
# 4096  22.117876  971.980740      637    8.2  13.9     Day
# 4097  22.046755  972.016674      640    8.5  13.9     Day
# 4098  22.051825  972.016674      643    8.8  14.7     Day
# 4099  22.132810  971.940215      643    8.9  15.4     Day
#
# [4100 rows x 14 columns]

# %%
# retirando as linhas com os 5% maiores valores e 5% menores valores
filtro = (dataset_exec5['level_0'] < 3895) & (dataset_exec5['level_0'] > 204) 
resultado = dataset_exec5[filtro]
resultado
# Out:
#       level_0  index    ID  day  hora  minuto  Datetime  Temperature  \
# 205       205    848   848   20    19      17  19:17:56    22.928682
# 206       206    477   477   20    19      13  19:13:50    22.928682
# 207       207    834   834   20    19      17  19:17:46    22.928682
# 208       208    841   841   20    19      17  19:17:51    22.928682
# 209       209    485   485   20    19      13  19:13:55    22.928682
# ...       ...    ...   ...  ...   ...     ...       ...          ...
# 3890     3890   3518  4418   21     6      45  06:45:50    26.880033
# 3891     3891   3516  4416   21     6      45  06:45:46    26.880033
# 3892     3892   3521  4421   21     6      45  06:45:55    26.885138
# 3893     3893   3517  4417   21     6      45  06:45:48    26.885138
# 3894     3894   3514  4414   21     6      45  06:45:43    26.885138
#
#        Humidity    Pressure  Co2 Gas  PM2,5  PM10 Daytime
# 205   34.430567  972.749919      632    4.6   9.2   Night
# 206   34.435567  972.749919      630    3.9   7.2   Night
# 207   34.435567  972.749919      631    4.4   8.4   Night
# 208   34.445565  972.805697      632    4.5   8.8   Night
# 209   34.455563  972.749919      630    4.1   7.5   Night
# ...         ...         ...      ...    ...   ...     ...
# 3890  23.246357  972.007828      574    5.7  10.7     Day
# 3891  23.302016  972.035892      577    5.7  10.7     Day
# 3892  23.180452  971.903412      574    5.4   9.6     Day
# 3893  23.215872  971.959541      574    5.7  10.7     Day
# 3894  23.463806  972.015670      576    5.7  10.1     Day
#
# [3690 rows x 14 columns]

# %%
sns.histplot(data=resultado, x='Humidity', bins=30, kde=True)
# Out:
# <Axes: xlabel='Humidity', ylabel='Count'>

# %%
sns.histplot(data=resultado, x='Temperature', bins=30, kde=True)
# Out:
# <Axes: xlabel='Temperature', ylabel='Count'>

# %%
# Instalando a biblioteca Kneed
# !pip install kneed

# Importando bibliotecas

import matplotlib.pyplot as plt
import pandas as pd
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kneed in /usr/local/lib/python3.10/dist-packages (0.8.3)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.22.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.10.1)

# %%
# Carregando a base de dados de sensores
base = pd.read_excel('/content/wine_final.xls')

# %%
# Limitando um pouco o tamanho da base para facilitar a interpretação dos dados
base = base.head(20000)
base
# Out:
#      class identifier  Alcohol  Malic acid   Ash  Alcalinity of ash  \
# 0                   1    14.23        1.71  2.43               15.6
# 1                   1    13.20        1.78  2.14               11.2
# 2                   1    13.16        2.36  2.67               18.6
# 3                   1    14.37        1.95  2.50               16.8
# 4                   1    13.24        2.59  2.87               21.0
# ..                ...      ...         ...   ...                ...
# 173                 3    13.71        5.65  2.45               20.5
# 174                 3    13.40        3.91  2.48               23.0
# 175                 3    13.27        4.28  2.26               20.0
# 176                 3    13.17        2.59  2.37               20.0
# 177                 3    14.13        4.10  2.74               24.5
#
#      Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# 0          127           2.80        3.06                  0.28
# 1          100           2.65        2.76                  0.26
# 2          101           2.80        3.24                  0.30
# 3          113           3.85        3.49                  0.24
# 4          118           2.80        2.69                  0.39
# ..         ...            ...         ...                   ...
# 173         95           1.68        0.61                  0.52
# 174        102           1.80        0.75                  0.43
# 175        120           1.59        0.69                  0.43
# 176        120           1.65        0.68                  0.53
# 177         96           2.05        0.76                  0.56
#
#      Proanthocyanins  Color intensity   Hue  OD280/OD315 of diluted wines  \
# 0               2.29             5.64  1.04                          3.92
# 1               1.28             4.38  1.05                          3.40
# 2               2.81             5.68  1.03                          3.17
# 3               2.18             7.80  0.86                          3.45
# 4               1.82             4.32  1.04                          2.93
# ..               ...              ...   ...                           ...
# 173             1.06             7.70  0.64                          1.74
# 174             1.41             7.30  0.70                          1.56
# 175             1.35            10.20  0.59                          1.56
# 176             1.46             9.30  0.60                          1.62
# 177             1.35             9.20  0.61                          1.60
#
#      Proline
# 0       1065
# 1       1050
# 2       1185
# 3       1480
# 4        735
# ..       ...
# 173      740
# 174      750
# 175      835
# 176      840
# 177      560
#
# [178 rows x 14 columns]

# %%
# Separando as variáveis independentes da variável-alvo.
features = base[['Alcohol', 'OD280/OD315 of diluted wines']]
true_labels = base[['class identifier', 'Alcalinity of ash', 'Malic acid', 'Ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Color intensity', 'Proanthocyanins', 'Hue', 'Proline']]

# %%
# Executando a normalização dos dados para execução do algoritmo
# O StandardScale normaliza aplicando o Z-score [z = (x - u)/s]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
scaled_features
# Out:
# array([[ 1.51861254,  1.84791957],
#        [ 0.24628963,  1.1134493 ],
#        [ 0.19687903,  0.78858745],
#        [ 1.69154964,  1.18407144],
#        [ 0.29570023,  0.44960118],
#        [ 1.48155459,  0.33660575],
#        [ 1.71625494,  1.36768901],
#        [ 1.3086175 ,  1.36768901],
#        [ 2.25977152,  0.33660575],
#        [ 1.0615645 ,  1.32531572],
#        [ 1.3580281 ,  0.78858745],
#        [ 1.38273339,  0.29423247],
#        [ 0.92568536,  0.40722789],
#        [ 2.16095032,  0.16711262],
#        [ 1.70390229,  0.54847218],
#        [ 0.77745356,  0.37897904],
#        [ 1.60508109,  0.05411719],
#        [ 1.02450655, -0.05887823],
#        [ 1.46920194,  0.29423247],
#        [ 0.78980621,  1.05695159],
#        [ 1.3086175 ,  1.55130658],
#        [-0.08723191,  1.28294244],
#        [ 0.87627476,  1.96091499],
#        [-0.18605311,  1.43831115],
#        [ 0.61686912,  1.70667528],
#        [ 0.06099988,  0.83096074],
#        [ 0.48098997,  0.8592096 ],
#        [ 0.36981612,  0.22361033],
#        [ 1.07391715,  1.1134493 ],
#        [ 1.2592069 ,  1.38181344],
#        [ 0.90098006,  0.13886376],
#        [ 0.71569031,  0.37897904],
#        [ 0.83921681,  0.36485461],
#        [ 0.93803801,  0.54847218],
#        [ 0.62922177,  0.36485461],
#        [ 0.59216382,  1.2123203 ],
#        [ 0.34511082,  0.23773476],
#        [ 0.06099988, -0.1436248 ],
#        [ 0.08570518,  0.1106149 ],
#        [ 1.50625989,  1.29706687],
#        [ 0.69098501,  1.08520045],
#        [ 0.50569527,  0.54847218],
#        [ 1.0862698 ,  1.33944015],
#        [ 0.29570023,  0.54847218],
#        [ 0.06099988,  1.04282716],
#        [ 1.49390724,  1.01457831],
#        [ 1.70390229,  1.16994702],
#        [ 1.1109751 ,  1.01457831],
#        [ 1.3580281 ,  0.19536147],
#        [ 1.1603857 ,  0.68971646],
#        [ 0.06099988,  0.42135232],
#        [ 1.02450655,  1.07107602],
#        [ 1.01215391,  0.91570731],
#        [ 0.95039066,  0.44960118],
#        [ 0.91333271,  0.83096074],
#        [ 0.69098501,  0.59084546],
#        [ 1.50625989,  0.98632945],
#        [ 0.35746347,  0.32248133],
#        [ 0.88862741,  0.36485461],
#        [-0.77898029, -1.11821035],
#        [-0.82839089, -1.33007677],
#        [-0.44545875, -1.44307219],
#        [ 0.82686416, -0.21424694],
#        [-0.77898029,  0.36485461],
#        [-1.02603329, -0.53910879],
#        [-0.77898029, -0.44023779],
#        [ 0.13511578,  0.80271188],
#        [-0.77898029,  1.22644473],
#        [ 0.41922672, -0.96284164],
#        [-0.97662269,  0.64734317],
#        [-0.87780149, -1.11821035],
#        [ 1.0615645 ,  0.77446303],
#        [ 0.60451647,  0.23773476],
#        [-0.01311602,  1.25469358],
#        [-1.28543893,  0.73208974],
#        [-1.65601842, -0.66622864],
#        [ 0.03629458, -0.18599809],
#        [-1.43367073, -0.12950037],
#        [-0.82839089, -0.42611337],
#        [-0.37134286,  0.73208974],
#        [-1.23602833,  0.71796531],
#        [-0.34663756,  0.74621417],
#        [-1.13720713,  0.15298819],
#        [ 0.06099988, -0.84984621],
#        [-1.43367073,  0.6614676 ],
#        [-0.4084008 ,  0.77446303],
#        [-1.03838594, -0.49673551],
#        [-1.66837107,  0.84508517],
#        [-1.68072372,  0.19536147],
#        [-1.13720713,  0.84508517],
#        [-1.13720713, -0.48261108],
#        [-1.23602833,  0.05411719],
#        [-0.38369551, -0.77922407],
#        [-0.87780149,  0.97220502],
#        [-1.70542902,  0.49197446],
#        [-0.6554538 ,  0.02586833],
#        [-1.47072867, -0.49673551],
#        [-0.87780149,  0.18123704],
#        [-0.77898029,  0.22361033],
#        [-0.87780149,  0.3083569 ],
#        [-1.13720713,  0.49197446],
#        [-0.49486935,  0.22361033],
#        [-0.81603824,  1.08520045],
#        [-1.45837602, -0.2424958 ],
#        [-0.6060432 ,  1.35356458],
#        [-0.71721705,  0.97220502],
#        [-0.92721209,  0.78858745],
#        [-0.34663756, -0.27074466],
#        [-0.96427004,  0.57672103],
#        [-1.71778167,  0.91570731],
#        [-1.90307141,  0.28010804],
#        [-0.59369055,  0.23773476],
#        [-1.53249192, -0.15774923],
#        [-1.96483466, -0.42611337],
#        [-1.13720713,  0.81683631],
#        [-2.43423535,  0.36485461],
#        [-1.45837602,  1.01457831],
#        [-0.71721705,  0.49197446],
#        [-0.28487431, -0.6944775 ],
#        [-1.23602833,  0.61909432],
#        [-1.91542406,  1.09932487],
#        [-1.77954492,  1.52305772],
#        [-0.71721705,  0.71796531],
#        [ 0.06099988,  0.68971646],
#        [-1.39661278,  1.45243558],
#        [-1.14955978,  0.94395616],
#        [-0.7048644 ,  0.32248133],
#        [-1.49543397, -0.2424958 ],
#        [-0.77898029,  0.23773476],
#        [-1.18661773, -0.05887823],
#        [-0.17370046, -1.86680504],
#        [-0.14899516, -1.68318747],
#        [-0.23546371, -1.76793404],
#        [-0.37134286, -1.86680504],
#        [-0.6060432 , -1.55606762],
#        [-0.49486935, -1.45719662],
#        [-0.92721209, -1.89505389],
#        [-0.5813379 , -1.30182791],
#        [ 0.60451647, -1.11821035],
#        [-0.19840576, -0.65210422],
#        [-0.08723191, -0.42611337],
#        [ 0.44393202, -0.20012252],
#        [ 0.64157442, -0.77922407],
#        [ 0.76510091, -0.7933485 ],
#        [-0.92721209, -0.86397064],
#        [ 0.19687903, -1.31595234],
#        [ 1.0862698 , -1.81030733],
#        [-0.16134781, -1.06171263],
#        [ 0.39452142, -1.40069891],
#        [ 0.09805783, -1.81030733],
#        [ 0.61686912, -1.85268061],
#        [-0.26016901, -1.61256533],
#        [ 0.13511578, -1.81030733],
#        [ 0.28334758, -1.55606762],
#        [-0.51957465, -1.49956991],
#        [ 0.20923168, -1.5984409 ],
#        [ 1.0368592 , -1.37245005],
#        [-0.6801591 , -1.2453302 ],
#        [ 1.65449169, -0.92046835],
#        [ 0.59216382, -1.17470806],
#        [-0.79133294, -1.45719662],
#        [ 0.85156946, -1.11821035],
#        [-0.18605311, -0.70860193],
#        [-0.05017396, -1.21708134],
#        [ 0.96274331, -1.31595234],
#        [ 0.90098006, -1.21708134],
#        [ 0.55510587, -1.48544548],
#        [-0.22311106, -1.21708134],
#        [ 0.71569031, -1.1464592 ],
#        [ 0.49334262, -0.97696606],
#        [-0.98897534, -1.10408592],
#        [-0.28487431, -1.38657448],
#        [ 1.43214399, -1.27357906],
#        [ 0.87627476, -1.23120577],
#        [ 0.49334262, -1.48544548],
#        [ 0.33275817, -1.48544548],
#        [ 0.20923168, -1.40069891],
#        [ 1.39508604, -1.42894777]])

# %%
# Visualizando a base de dados
fig, ax1= plt.subplots(figsize=(8, 6))
ax1.scatter(scaled_features[:, 0], scaled_features[:, 1])

# %%
# Instanciando o algoritmo K-Means
kmeans = KMeans(init='random', n_clusters=3, n_init=10, max_iter=300, random_state=42)
# Aplicando o algoritmo
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=3, n_init=10, random_state=42)

# %%
# Algumas informações sobre o processo de treinamento
# O valor do SSE (Sum of the Squared Error) mais baixo
# O SSE é definido como a soma dos quadrados das distâncias euclidianas de cada ponto ao seu respectivo centróide.
# Por ser uma medida de erro, o objetivo do K-Means é minimizá-la.
kmeans.inertia_ # SSE
# Out:
# 99.1143935069117

# %%
# Coordenadas finais dos centróides
kmeans.cluster_centers_
# Out:
# array([[-1.1233104 ,  0.39915679],
#        [ 0.88140586,  0.75381963],
#        [ 0.09849126, -1.25177292]])

# %%
# Número de iterações necessárias para alcançar a convergência
kmeans.n_iter_
# Out:
# 9

# %%
# Olhando os grupos estabelecidos pelo algoritmo para os dados iniciais
kmeans.labels_[:5]
# Out:
# array([1, 1, 1, 1, 1], dtype=int32)

# %%
# Visualizando com os grupos definidos
fig, ax1= plt.subplots(figsize=(8, 6))
fte_colors = {0:'red', 1:'green', 2:'blue'}
km_colors = [fte_colors[label] for label in kmeans.labels_]
ax1.scatter(scaled_features[:, 0], scaled_features[:, 1], c=km_colors)

# %%
# E como descobrir o número K?

# Podemos usar o método do cotovelo.
# Calculando SSEs para vários Ks e armazenando os resultados em uma lista
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)


# Visualizando
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel('Number of Clusters')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %%
# Porém, nem sempre a escolha do melhor K é tão óbvia. Vamos usar uma biblioteca para isso.
kl = KneeLocator(range(1, 11), sse, curve='convex', direction='decreasing')
kl.elbow
# Out:
# 3

# %%
# Outra forma de escolha é através de uma métrica chamada Coeficiente Silhouette
'''
The silhouette coefficient is a measure of cluster cohesion and separation. 
It quantifies how well a data point fits into its assigned cluster based on two factors:
- How close the data point is to other points in the cluster
- How far away the data point is from points in other clusters
Silhouette coefficient values range between -1 and 1. 
Larger numbers indicate that samples are closer to their clusters than they are to other clusters.

In the scikit-learn implementation of the silhouette coefficient, the average 
silhouette coefficient of all the samples is summarized into one score. 
The silhouette score() function needs a minimum of two clusters, or it will raise an exception.
'''

# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# Visualizando
plt.plot(range(2, 11), silhouette_coefficients)
plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
# Out:
# Text(0, 0.5, 'Silhouette Coefficient')
